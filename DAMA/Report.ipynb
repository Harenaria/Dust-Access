# %%
from IPython.display import Markdown
import importlib
import report_functions as rf

importlib.reload(rf)
report_data = rf.load_tiered_data()

# %% [markdown]
# # Dust Access - Meta Analysis Report
#
# This report analyzes MCTS simulation data to identify card power levels, deck balance, and matchup dynamics.

# %% [markdown]
# ## AI Meta-Game Analysis Summary
# A natural language summary of the current meta state using Gemini.

# %%
API_KEY = rf.gemini_api_key()
if API_KEY:
    report_data = rf.load_tiered_data()
    summary = rf.get_ai_summary(report_data, API_KEY)
    display(Markdown(summary))
else:
    display(Markdown("### API Key Missing. Please create `.gemini_api` file."))
# Out:
# **To: Game Design Team**
# **From: Lead Balance Designer**
# **Subject: Post-Simulation Balance Report - 'Dust Access' Alpha Structure Decks**
#
# The latest MCTS AI playtests indicate significant balance outliers and structural issues. With Fun Scores currently below 50/100 in both Casual and Competitive simulations, the game is suffering from a "stale meta" where a handful of cards dominate early-game progression while others act as "trap cards" for players.
#
# ### **Engagement & Skill Gap Analysis**
# *   **Fun Scores (47.5/43.2):** These are critically low. The data suggests games are being decided by Level 1-2 equipment efficiency rather than late-game specialization or skillful Chain execution.
# *   **Skill Gap:** The gap is wide but unhealthy. High-skill bots are finding "infinite-value" loops with specific low-level items (e.g., *Second Wind*, *Wooden Shield*), while Casual bots are being crushed by high-Tenacity stat-sticks.
#
# ### **Universal Threats (Nerfs Required)**
# ...

# %% [markdown]
# ## Skill Scalability
# How decks and cards perform in relation to the player skill level.

# %%
rf.plot_skill_scalability(report_data)

# %% [markdown]
# ## Deck and Matchup Performance
# Overall winrates across all matchups.

# %% [markdown]
# #### Competitive-level AI

# %%
rf.plot_deck_performance(report_data, target_tier='Competitive')
rf.plot_matchup_matrix(report_data, target_tier='Competitive')
rf.plot_matchup_duration(report_data, target_tier='Competitive')

# %% [markdown]
# #### Advanced-level AI

# %%
rf.plot_deck_performance(report_data, target_tier='Advanced')
rf.plot_matchup_matrix(report_data, target_tier='Advanced')
rf.plot_matchup_duration(report_data, target_tier='Advanced')

# %% [markdown]
# #### Casual-level AI

# %%
rf.plot_deck_performance(report_data, target_tier='Casual')
rf.plot_matchup_matrix(report_data, target_tier='Casual')
rf.plot_matchup_duration(report_data, target_tier='Casual')

# %% [markdown]
# ## Card Efficiency
# Efficiency is defined as `Winrate - ExpectedWinrate(Level)`.

# %% [markdown]
# #### Competitive-level AI

# %%
rf.plot_card_efficiency(report_data, target_tier='Competitive')

# %% [markdown]
# #### Advanced-level AI

# %%
rf.plot_card_efficiency(report_data, target_tier='Advanced')

# %% [markdown]
# #### Casual-level AI

# %%
rf.plot_card_efficiency(report_data, target_tier='Casual')

# %% [markdown]
# ## Fun Score

# %% [markdown]
# #### Competitive-level AI

# %%
rf.plot_fun_analysis(report_data, target_tier='Competitive')

# %% [markdown]
# #### Advanced-level AI

# %%
rf.plot_fun_analysis(report_data, target_tier='Advanced')

# %% [markdown]
# #### Casual-level AI

# %%
rf.plot_fun_analysis(report_data, target_tier='Casual')

# %% [markdown]
# ## Leaderboards

# %% [markdown]
# #### Competitive-level AI

# %%
rf.display_top_cards(report_data, target_tier='Competitive')
rf.display_underperforming_cards(report_data, target_tier='Competitive', min_plays=20)
# Out:
# ### Top Cards (Competitive)
# <style type="text/css">
# </style>
# <table id="T_c1c02">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c1c02_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_c1c02_level0_col1" class="col_heading level0 col1" >Level</th>
#       <th id="T_c1c02_level0_col2" class="col_heading level0 col2" >WinRate</th>
#       <th id="T_c1c02_level0_col3" class="col_heading level0 col3" >Efficiency</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c1c02_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c1c02_row0_col0" class="data row0 col0" >Large Club</td>
#       <td id="T_c1c02_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_c1c02_row0_col2" class="data row0 col2" >97.77%</td>
#       <td id="T_c1c02_row0_col3" class="data row0 col3" >+48.77%</td>
#     </tr>
#     <tr>
#       <th id="T_c1c02_level0_row1" class="row_heading level0 row1" >23</th>
# ...

# %% [markdown]
# #### Advanced-level AI

# %%
rf.display_top_cards(report_data, target_tier='Advanced')
rf.display_underperforming_cards(report_data, target_tier='Advanced', min_plays=20)
# Out:
# ### Top Cards (Advanced)
# <style type="text/css">
# </style>
# <table id="T_cee9b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cee9b_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_cee9b_level0_col1" class="col_heading level0 col1" >Level</th>
#       <th id="T_cee9b_level0_col2" class="col_heading level0 col2" >WinRate</th>
#       <th id="T_cee9b_level0_col3" class="col_heading level0 col3" >Efficiency</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cee9b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cee9b_row0_col0" class="data row0 col0" >Large Club</td>
#       <td id="T_cee9b_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_cee9b_row0_col2" class="data row0 col2" >95.85%</td>
#       <td id="T_cee9b_row0_col3" class="data row0 col3" >+46.85%</td>
#     </tr>
#     <tr>
#       <th id="T_cee9b_level0_row1" class="row_heading level0 row1" >30</th>
# ...

# %% [markdown]
# #### Casual-level AI

# %%
rf.display_top_cards(report_data, target_tier='Casual')
rf.display_underperforming_cards(report_data, target_tier='Casual', min_plays=20)
# Out:
# ### Top Cards (Casual)
# <style type="text/css">
# </style>
# <table id="T_1d3eb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1d3eb_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_1d3eb_level0_col1" class="col_heading level0 col1" >Level</th>
#       <th id="T_1d3eb_level0_col2" class="col_heading level0 col2" >WinRate</th>
#       <th id="T_1d3eb_level0_col3" class="col_heading level0 col3" >Efficiency</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1d3eb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1d3eb_row0_col0" class="data row0 col0" >Large Club</td>
#       <td id="T_1d3eb_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_1d3eb_row0_col2" class="data row0 col2" >89.10%</td>
#       <td id="T_1d3eb_row0_col3" class="data row0 col3" >+40.10%</td>
#     </tr>
#     <tr>
#       <th id="T_1d3eb_level0_row1" class="row_heading level0 row1" >21</th>
# ...

# %% [markdown]
# ## Card Overview

# %%
rf.display_searchable_table(report_data)
