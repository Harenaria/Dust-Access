# %% [markdown]
# # Dust Access - Meta Analysis Report
#
# This report analyzes MCTS simulation data to identify card power levels, deck balance, and matchup dynamics.

# %% [markdown]
# ## 0. AI Meta-Analysis Summary
# Generate a natural language summary of the current meta state using Gemini.

# %%
from IPython.display import Markdown
import importlib
import report_functions as rf

# Force reload in case the file was updated while the kernel was running
importlib.reload(rf)

# 1. Get a free API Key at https://aistudio.google.com/app/apikey
# 2. Paste it here:
API_KEY = "AIzaSyChfV1t2GUQ9Y9psdYsy2AOxiXRIuMyQ6Y"

data = rf.load_data()
summary = rf.get_ai_summary(data, API_KEY)
display(Markdown(summary))

# %% [markdown]
# ## 1. Deck Performance
# Overall winrates across all matchups.

# %%
rf.plot_deck_performance(data)

# %% [markdown]
# ## 2. Matchup Data
# Detailed win percentage and match duration Heatmaps (Player vs Opponent).

# %%
rf.plot_matchup_matrix(data)

# %%
rf.plot_matchup_duration(data)

# %% [markdown]
# ## 3. Card Efficiency (Level-based)
# Efficiency is defined as `Winrate - ExpectedWinrate(Level)`.
#
# Horizontal lines represent the "Fair" target for each card level (Lvl 1 = 44% to Lvl 5 = 60%).

# %%
rf.plot_card_efficiency(data)

# %% [markdown]
# ## 4. Fun Score

# %%
rf.plot_fun_analysis(data)

# %% [markdown]
# ## 4. Leaderboards

# %%
rf.display_top_cards(data)

# %%
rf.display_underperforming_cards(data, min_plays=20)

# %% [markdown]
# #### Card List

# %%
df = rf.prepare_card_df(data)
rf.display_searchable_table(df)
